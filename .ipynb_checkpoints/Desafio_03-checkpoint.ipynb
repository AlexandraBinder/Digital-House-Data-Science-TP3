# %% [markdown]
# # DESAFIO III
# # Clasificación de jugadores de la NBA según posición de juego
# #### Grupo 5
# 1. Alexandra Binder
# 2. Verónica Nieves

# %% [markdown]
# ---
# ## Introducción
#
# El objetivo final a concretarse en el Desafío 3, es lograr clasificar en qué posición juega un jugador de la NBA. Para ello vamos a utilizar el dataset llamado `2021-2022 NBA Player Stats`, correspondiente a las estadísticas de jugadores de la NBA de la temporada regular 2021-2022 por partido. Los datos se encuentran disponibles en:
#
# https://www.kaggle.com/vivovinco/nba-player-stats/version/1
#
# **Las features del dataset son las siguientes:**
#
# - Rk : Rank
# - Player : Nombre
# - **Pos : Posición**
# - Age : Edad
# - Tm : Equipo
# - G : número de juegos
# - GS : juegos comenzados
# - MP : minutos jugados por juego
# - FG : encestados por partido
# - FGA : intentos de encesto por partido
# - FG% : porcentaje de encesto por partido
# - 3P : canastas de 3 puntos por partido
# - 3PA : intentos de canastas de 3 puntos por partido
# - 3P% : porcentaje de canastas de 3 puntos por partido
# - 2P : canastas de 2 puntos por partido
# - 2PA : intentos de canasta de 2 puntos por partido
# - 2P% : porcentaje de canastas de 2 puntos por partido
# - eFG% : porcentaje efectivo de canastas
# - FT : tiros libres por juego
# - FTA : intentos de tiros libres por juego
# - FT% : porcentaje de tiros libres
# - ORB : rebotes ofensivos por partido
# - DRB : rebote defensivo por partido
# - TRB : total de rebotes por juego
# - AST : asistencias por partido
# - STL : robos por juego
# - BLK : bloques por juego
# - TOV : perdidas del balón por partido
# - PF : faltas personales por partido
# - PTS : puntos por juego
#
# Este dataset fue seleccionado por dos razones principales: Por un lado, contiene una feature categórica que ya viene relativamente balanceada (cada categoría contiene alrededor del 20% de los datos); por otro lado contiene varias features de tipo numérico que permiten a los modelos abstraer información de tipo variada para predecir la posición de un jugador.

# %% [markdown]
# El objetivo es aplicar los modelos de clasificación para el campo `posición` en donde tenemos las siguientes categorias:
# - **1 - PF:**	Point Forward
# - **2 - SG:**	Shooting Guard
# - **3 - SF:**	Small Forward
# - **4 - PG:**	Power Forward
# - **5 - C:**  Center
# <br><br>
# <img src="img/positions.png" alt="position-map" width="300"/>

# %% [markdown]
# ### **Objetivos del Desafío 3**
# - **Entrenar al menos tres modelos de clasificación distintos sobre estos datos**: De ser necesario aplicar una estrategia para balancear las categorías a clasificar. Normalizar los datos y aplicar regularización a los mismos. Aplicar GridSearch o RandomSearch para determinar los hiperparámetros óptimos de cada modelo. Van a utilizarse los siguientes modelos:
#     - Naive Bayes (benchmark)
#     - Regresión Logística
#     - Modelo KNN
#
#
# - **Evaluar la performance de los modelos y comparar ventajas y desventajas de cada uno.**
#
# - **Determinar la importancia de las features incluidas en la predicción. Intrepretar.**

# %% [markdown]
# ---
#
# <a id="indice"></a>
# ## **Índice**
#
# [Módulo 1 - Primer acercamiento](#modulo_01)
#
# [Módulo 2 - Naive Bayes (benchmark)](#modulo_02)
#
# [Módulo 3 - Modelos de clasificación](#modulo_03)
#
#    [  * 3.1 Modelo KNN](#modelo_KNN)
#
#    [  * 3.2 Regresión Logística](#modelo_RL)
#
#    [  * 3.3 Árboles de clasificación](#modelo_AC)
#
#
# [Módulo 4 - Evaluación y comparación de modelos](#modulo_04)
#
#
# [Conclusión](#modulo_05)
#
# ---

# %% [markdown]
# <a id="modulo_01"></a>
# ## Módulo 1 - Primer acercamiento
# [Ir a índice](#indice)
#
# En esta primera sección vamos a explorar los datos y reducir el número de columnas, dejando solo aquellas que aportan información relevante para la clasificación.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("2021-2022 NBA Player Stats V0.csv", sep=';', encoding='latin')
df.head()
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0   1   Precious Achiuwa   C   22  TOR  34  20  25.3  3.4   8.1  ...  0.574
# 1   2       Steven Adams   C   28  MEM  44  43  25.7  2.6   4.9  ...  0.566
# 2   3        Bam Adebayo   C   24  MIA  21  21  32.9  6.9  13.3  ...  0.767
# 3   4       Santi Aldama  PF   21  MEM  25   0  10.5  1.4   3.8  ...  0.579
# 4   5  LaMarcus Aldridge   C   36  BRK  32  10  23.1  5.9  10.3  ...  0.862
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.4  5.3   7.7  1.3  0.6  0.6  1.1  2.2   7.9
# 1  4.3  4.9   9.3  3.0  1.0  0.6  1.6  1.7   6.7
# 2  2.6  7.3  10.0  3.2  1.2  0.5  2.9  3.1  18.7
# 3  0.9  1.6   2.5  0.5  0.1  0.2  0.3  0.9   3.4
# 4  1.5  4.1   5.7  0.9  0.4  1.1  0.8  1.7  13.8
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      590 non-null    int64
#  1   Player  590 non-null    object
#  2   Pos     590 non-null    object
#  3   Age     590 non-null    int64
#  4   Tm      590 non-null    object
#  5   G       590 non-null    int64
#  6   GS      590 non-null    int64
#  7   MP      590 non-null    float64
#  8   FG      590 non-null    float64
#  9   FGA     590 non-null    float64
#  10  FG%     590 non-null    float64
#  11  3P      590 non-null    float64
#  12  3PA     590 non-null    float64
#  13  3P%     590 non-null    float64
#  14  2P      590 non-null    float64
#  15  2PA     590 non-null    float64
#  16  2P%     590 non-null    float64
#  17  eFG%    590 non-null    float64
#  18  FT      590 non-null    float64
#  19  FTA     590 non-null    float64
#  20  FT%     590 non-null    float64
#  21  ORB     590 non-null    float64
#  22  DRB     590 non-null    float64
#  23  TRB     590 non-null    float64
#  24  AST     590 non-null    float64
#  25  STL     590 non-null    float64
#  26  BLK     590 non-null    float64
#  27  TOV     590 non-null    float64
#  28  PF      590 non-null    float64
#  29  PTS     590 non-null    float64
# dtypes: float64(23), int64(4), object(3)
# memory usage: 138.4+ KB

# %% [markdown]
# Tenemos un total de 590 registros y 30 columnas, de las cuales 4 son de tipo **int**, 3 del tipo **object** y el resto son de tipo **float**. Dado que no hay registros nulos, no es necesario eliminar registros incompletos, o completarlos por métodos de imputación.

# %% [markdown]
# ---
# ### 1.1. Limpieza de datos anómalos

# %% [markdown]
# ### 1.1.1. Features categóricas

# %% [markdown]
# Eliminamos las variables `Player`y `Tm` (team) ya que son features categóricas y no inciden en el trabajo de clasificación de posición de juego.

# %%
# quitamos la columna del "Player" y "Tm"
df.drop(columns=['Player', 'Tm'], inplace=True)

# %% [markdown]
# ### 1.1.2. Target feature

# %% [markdown]
# Armamos una tabla que identifique las diferentes categorías en el feature de posiciones `Pos` y que contabilice la cantidad de registros pertenecientes a cada categoría y los porcentajes asociados a las mismas. Esto último se hace con el objetivo de definir si es necesario balancear o no las categorías para evitar desbalances en las estimaciones.

# %%
# resumen de posición "pos" 
df_pos = pd.DataFrame({'#': df['Pos'].value_counts().values})
df_pos.index = df['Pos'].value_counts().index
df_pos['%'] = [((x/df_pos['#'].sum())*100).round(2) for x in df_pos['#']]
print("Total amount of registers = ", df.shape[0])
df_pos
# Out:
# Total amount of registers =  590
#       #      %
# SG  145  24.58
# SF  122  20.68
# PG  110  18.64
# PF  109  18.47
# C   104  17.63

# %% [markdown]
# Se observa que contamos con un dataset con un `total de 590 registros` donde cada categoría target contiene aproximadamente el 20% de los datos. Como los datos se encuentran mas o menos balanceados, decidimos `mantener todos los datos` y `no balancear más las categorías`.
#
# De haber rebajado cada categoría a 104 registros cada una para buscar balancear a la perfección los datos, se habría perdido más del 14% de los registros, lo cual no es conveniente.

# %% [markdown]
# ### 1.1.3. Feature Rk

# %% [markdown]
# Los valores de ranking no pueden ser negativos y no deberían superar el valor de 590 debido a la cantidad de registros que tenemos

# %%
(df['Rk'] <= 0).value_counts()
# Out:
# False    590
# Name: Rk, dtype: int64

# %%
(df['Rk'] > 590).value_counts()
# Out:
# False    590
# Name: Rk, dtype: int64

# %% [markdown]
# ### 1.1.4. Feature Age
# Mientras está establecido que la edad mínima para jugar en la NBA es de 18 años; la edad máxima no se encuentra definida. Sin embargo los registros muestran que el jugador de mayor edad en retirarse de la NBA fue Nat Hickey con casi 46 años. (Según wikipedia)

# %%
(df['Age'] < 18).value_counts()
# Out:
# False    590
# Name: Age, dtype: int64

# %%
(df['Age'] > 46).value_counts()
# Out:
# False    590
# Name: Age, dtype: int64

# %% [markdown]
# ### 1.1.5. Features restantes
# Los features restantes presentan la característica que deben ser mayor o igual a cero, independientemente si son del tipo *int64* o *float64*

# %%
for col in df.columns:
    if df[col].dtypes != "object":
        val_c = (df[col] >= 0).value_counts()
        if not any(val_c.keys()):
            print(col)
            print(val_c)

# %% [markdown]
# En este caso todos los features cumplen con este requisito.
#
# Los features pueden dividirse en dos categorías diferentes: aquellos con valores porcentuales y aquellos con valores de medias calculadas por partido. Como estos últimos no contienen más restricciones que aquellas mencionadas anteriormente, no es necesario seguir investigando; pero en el caso de los valores porcentuales, es necesario corroborar que estos no superen el valor de 1 o 100%.

# %%
perc_feat = [x for x in df.columns if '%' in x]
perc_feat
# Out:
# ['FG%', '3P%', '2P%', 'eFG%', 'FT%']

# %%
for col in perc_feat:
        val_c = (df[col] > 1).value_counts()
        if any(val_c.keys()):
            print(col)
            print(val_c)

# %% [markdown]
# Los features cumplen con este requisito.
#
# De esta manera damos por terminada la limpieza de datos de nuestro dataset en lo que respecta la búsqueda de datos anómalos.

# %% [markdown]
# ---
# ### 1.2. Convertir en dummies las variables categóricas

# %% [markdown]
# Hacemos esto para poder graficar correctamente la matriz de correlación

# %%
print('Target feature unique values:')
print(df['Pos'].unique())
print("Original df size: ", df.shape)
# Out:
# Target feature unique values:
# ['C' 'PF' 'SG' 'PG' 'SF']
# Original df size:  (590, 28)

# %%
dummies = pd.get_dummies(df['Pos'], prefix="Pos", drop_first=False)
df = pd.concat([df, dummies], axis=1)
print("New df size: ", df.shape)
df.columns
# Out:
# New df size:  (590, 33)
# Index(['Rk', 'Pos', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Pos_C', 'Pos_PF',
#        'Pos_PG', 'Pos_SF', 'Pos_SG'],
#       dtype='object')

# %% [markdown]
# Procedemos a guardar la versión a ser utilizada en los modelos.

# %%
# Generamos una nueva versión del dataset
df.to_csv("data_for_analyzing.csv", index=False)

# %% [markdown]
# ---
# <a id="sec_1.3"></a>
# ### 1.3. Análisis exploratorio de los datos

# %%
df = pd.read_csv("data_for_analyzing.csv", index_col=False)

# %% [markdown]
# Buscamos analizar qué variables se encuentran más correlacionadas con cada una de las categorías:

# %%
df_nopos = df.drop(columns="Pos")
pos_list = [x for x in df_nopos.columns if "Pos" in x]

fig, ax = plt.subplots(1, 5, figsize=(30,10))
i = 0
for pos in pos_list:
    sns.heatmap(df_nopos.corr()[[pos]], annot=True, vmin=-1, cmap="YlGnBu", square=False, ax=ax[i])
    i += 1

# %% [markdown]
# A partir de lo calculado podemos identificar las siguientes correlaciones (sin contemplar los target features):
# - **Posición C:**
#     - *más corr:* ORB, BLK, TRB, DRB, FG%
#     - *menos corr:* 3PA, 3P, 3P%, AST
#
#
# - **Posición PF:**
#     - *más corr:* TRB, DRB, ORB, BLK
#     - *menos corr:* AST
#
#
# - **Posición PG:**
#     - *más corr:* AST, TOV, STL, 3PA, FGA
#     - *menos corr:* ORB, BLK, TRB
#
#
# - **Posición SF:**
#     - *más corr:* 3P%
#     - *menos corr:* AST, BLK
#
#
# - **Posición SG:**
#     - *más corr:* 3PA, 3P
#     - *menos corr:* ORB, TRB, BLK, DRB, PF

# %% [markdown]
# Como trabajamos con varios features, para generar un pairplot legible es necesario seleccionar algunas features relevantes. Optamos por seleccionar aquellas features con mayor módulo de correlación con respecto a las categorias.

# %%
most_corr_feat = ["ORB", "TRB", "AST", "3PA", "3P%", "Pos"]
df_nodummies = df.drop(columns=pos_list)
df_pairplot = df_nodummies[most_corr_feat]
sns.pairplot(df_pairplot, hue="Pos")

# %% [markdown]
# Podemos observar que en general es dificil distinguir una categoría de otra en cada cruce de datos. No obstante parecería que la feature `AST` es una de las que mejor logra diferenciar los distintos conjuntos de datos.
#
#
# Ahora podemos calcular y observar la correlación entre los features que no son target

# %%
df_notarget = df.drop(columns=pos_list)
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(df_notarget.corr(), annot=True, vmin=-1, cmap="YlGnBu", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# En este heatmap se observa que existen conjuntos de características que parecen presentar un cierto nivel de colinealidad entre si:
# - FG, FGA, FG%
# - 3P, 3PA, 3P%
# - 2P, 2PA, 2P%
# - FT, FTA, FT%
#
# Una vez finalizado el análisis exploratorio, eliminamos las columnas innecesarias y continuamos a la siguiente parte del trabajo donde generamos, entrenamos y evaluamos diferentes modelos de clasificación.

# %%
# Generamos una nueva versión del dataset
df_nodummies.to_csv("data_for_models.csv", index=False)

# %% [markdown]
# ---
# <a id="modulo_02"></a>
# ## Módulo 2 - Benchmark
# [Ir a índice](#indice)
#
# En este módulo vamos a desarrollar le modelo de Naive Bayes que tomaremos como benchmark para evaluar y mejorar los modelos del siguiente módulo. <br><br> Antes de comenzar, vamos a definir tres combinaciones diferentes de features a utilizar en los modelos por lo generamos tres train_test_split acorde a cada uno de ellos. Estas variables van a ser llamadas a lo largo de la notebook.

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score, KFold

# %%
data = pd.read_csv("data_for_models.csv")
data.head(2)
# Out:
#    Rk Pos  Age   G  GS    MP   FG  FGA    FG%   3P  ...    FT%  ORB  DRB  TRB  \
# 0   1   C   22  34  20  25.3  3.4  8.1  0.412  0.3  ...  0.574  2.4  5.3  7.7
# 1   2   C   28  44  43  25.7  2.6  4.9  0.521  0.0  ...  0.566  4.3  4.9  9.3
#
#    AST  STL  BLK  TOV   PF  PTS
# 0  1.3  0.6  0.6  1.1  2.2  7.9
# 1  3.0  1.0  0.6  1.6  1.7  6.7
#
# [2 rows x 28 columns]

# %%
# Definimos X a partir de la lista de features
X = data.drop(columns='Pos')
Y = data.Pos

# separamos train y test con proporción 70-30
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, stratify=Y, random_state = 123)

features_1 = data.drop(columns='Pos').columns
features_2 = ['Rk', 'Age', 'G', 'GS', 'MP', 'FG', '3P', '2P', 'eFG%', 'FT', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
features_2 = ["ORB", "AST", "FG%"]
features_3 = ["ORB", "TRB", "AST", "3PA", "3P%"]

# Como Y es una única columna y los índices son iguales, no es necesario generar una variable aparte diferenciando features
X_train_1 = X_train[features_1]
X_test_1 = X_test[features_1]

X_train_2 = X_train[features_2]
X_test_2 = X_test[features_2]

X_train_3 = X_train[features_3]
X_test_3 = X_test[features_3]

# Generamos un dataframe donde vamos a contabilizar los resultados de cada modelo
resultados = pd.DataFrame(columns=['Accuracy', 'Confusion Matrix', 'Feature ID', 'Modelo'])

# %% [markdown]
# Utilizaremos validación cruzada para determinar que features nos ayudan a realizar mejores predicciones

# %% [markdown]
# A continuación vamos a evaluar distintos subconjuntos de features con el objetivo de identificar el conjunto que ayuda a generar mejores precicciones. Pero antes de eso, vamos a definir la función `cv_gnb` que recibe los conjuntos train y test, evalua el performance de modelo con cross validation, posteriormente evalúa el modelo Naive Bayes Gaussiano,`gnb`, calcula el accuracy y muestra la matriz deconfusión.

# %%
def cv_gnb (X_train, X_test, Y_train, Y_test, feature_id, k_folds=10):
    
    # ajustamos y aplicamos el modelo
    gnb = GaussianNB()
    
    # definimos la configuración para cross validation y lo aplicamos
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=12)
    cv_scores = cross_val_score(gnb, X_train, Y_train, cv=kf)
    
    # imprimimos la media, el mínimo y máximo de los scores
    print( "Media de cv_scores:\t{}%".format(round(cv_scores.mean()*100,2)))
    print( "Min de cv_scores:\t{}%".format(round(cv_scores.min()*100,2)))
    print( "Max de cv_scores:\t{}%".format(round(cv_scores.max()*100,2)))
    print('CV scores:\n', cv_scores)
    
    # ajustamos y aplicamos el modelo
    gnb.fit(X_train, Y_train)
    Y_pred = gnb.predict(X_test)

    # Generamos la matriz de confusion
    conf_matrix = confusion_matrix(Y_test, Y_pred)
    ax = sns.heatmap(conf_matrix, annot=True, xticklabels = Y.unique(), yticklabels = Y.unique(), linewidths=.5, cmap="YlGnBu")
    ax.set(xlabel='Prediction', ylabel='Ground truth', title="Confusion Matrix")

    acc = accuracy_score(Y_test, Y_pred)
    print("\nAccuracy = ", acc)
    print("\n")
    note = 'Naive Bayes con CV 10 fold'

    resultados.loc[len(resultados.index)] = [acc, conf_matrix, feature_id, note]

# %%
# COMBINACIÓN 1 - TODAS LAS FEATURES
cv_gnb(X_train_1, X_test_1, Y_train, Y_test, 1)
# Out:
# Media de cv_scores:	37.53%
# Min de cv_scores:	24.39%
# Max de cv_scores:	46.34%
# CV scores:
#  [0.4047619  0.33333333 0.4047619  0.3902439  0.3902439  0.36585366
#  0.46341463 0.41463415 0.24390244 0.34146341]
#
# Accuracy =  0.3615819209039548

# %%
# COMBINACIÓN 2 - eliminando features con colinalidad (eliminamos intentos y valores porcentuales)
cv_gnb(X_train_2, X_test_2, Y_train, Y_test, 2)
# Out:
# Media de cv_scores:	44.31%
# Min de cv_scores:	26.83%
# Max de cv_scores:	60.98%
# CV scores:
#  [0.47619048 0.4047619  0.42857143 0.46341463 0.48780488 0.48780488
#  0.6097561  0.46341463 0.26829268 0.34146341]
#
# Accuracy =  0.4067796610169492

# %%
# COMBINACIÓN 3 - features de mayor correlación absoluta
cv_gnb(X_train_3, X_test_3, Y_train, Y_test, 3)
# Out:
# Media de cv_scores:	44.79%
# Min de cv_scores:	26.83%
# Max de cv_scores:	60.98%
# CV scores:
#  [0.5        0.45238095 0.4047619  0.48780488 0.51219512 0.46341463
#  0.6097561  0.41463415 0.26829268 0.36585366]
#
# Accuracy =  0.4011299435028249

# %%
resultados[0:3]
# Out:
#    Accuracy                                   Confusion Matrix Feature ID  \
# 0  0.361582  [[19, 2, 0, 0, 10], [8, 8, 2, 3, 12], [0, 1, 1...          1
# 1  0.406780  [[18, 4, 0, 3, 6], [9, 11, 1, 4, 8], [0, 1, 11...          2
# 2  0.401130  [[17, 2, 0, 4, 8], [9, 8, 1, 4, 11], [0, 1, 11...          3
#
#                        Modelo
# 0  Naive Bayes con CV 10 fold
# 1  Naive Bayes con CV 10 fold
# 2  Naive Bayes con CV 10 fold

# %% [markdown]
# Podemos observar que para el modelo Naive Bayes Gaussiano, en general el acuraccy es muy bajo (entre 36.16% - 40.67%). De las tres combinaciones de features que fueron probadas la tercera fue la que obtuvo un mejor accuracy score. En ella se utilizan las siguientes features: ["ORB", "TRB", "AST", "3PA", "3P%"].
#
# De la matrices de confusión se observa los siguiente:
#
#   * `SF` es la categoría con mayor cantidad de predicciones correctas, pero también es la categoría con mayor predicciones incorrectas _(columna 5)_ lo que genera un error de clasificación alto. En otras palabras podemos decir que el modelo clasifica correctamente a `SF` pero no el resto de las categorías.
#
#
#   * `PG` es la categoría con menor cantidad de predicciones _(columna 4)_. Solamente se tienen algunas predicciones correctas en el caso de la _combinación 3_, mientras que para las combinaciones 1 y 2, no se tiene ninguna predicción asertada en la diagonal. Esto ocurre a pesar de que el dataset original se encuentre balanceado. Es decir, el modelo no aprendió a clasificar correctamente a esta categoría.

# %% [markdown]
# ---
# <a id="modulo_03"></a>
# ## Módulo 3 - Modelos de Clasificación
# [Ir a índice](#indice)
#
# [  * Modelo KNN](#modelo_KNN)
#
# [  * Modelo de Regresión Logística](#modelo_LR)
#
# [  * Modelo Árboles de clasificación](#modelo_AC)

# %% [markdown]
# En este módulo vamos a evaluar el performance de tres módelos de clasificación y lo vamos a comparar con el desempeño del modelo benchmark, el modelo Naive Bayes revisado previamente. En cada módelo se consideró lo siguiente:
#
# * Aplicación del modelo base
#
# * Busqueda de hiperparámetros optimos (GridSearch/RandomSearch)
#
# La evaluación y comparación de los modelos se revisará en el siguiente módulo.
#
# Recordemos que estamos trabajando con un problema de clasificación multicase, con cinco categorias (**n=5**) que se refieren a las posiciones de los jugadores (**C**, **PF**, **SG**, **PG**, **SF**). En este problema las etiquetas son mutuamente excluyentes, es decir, que a cada registro se le puede asignar una y solo una etiqueta.

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import tree
from IPython.display import Image
import pydotplus

# %% [markdown]
# ---
# <a id="modelo_KNN"></a>
# #### 3.1 Modelo KNN
# [Ir al inicio del módulo 3](#modulo_03)

# %% [markdown]
# A continuación vamos a evaluar el modelo KNN usando cross validation, pero primero vamos a estandarizar la matriz de features para eliminar sus distintas unidades de medida y evitar distorciones debidas a disparidad de escalas. Esto es importante ya que KNN es un método que se basa en calcular distancias.

# %%
scaler = StandardScaler()

X_train_1_std = scaler.fit_transform(X_train_1)
X_train_2_std = scaler.fit_transform(X_train_2)
X_train_3_std = scaler.fit_transform(X_train_3)

X_test_1_std = scaler.fit_transform(X_test_1)
X_test_2_std = scaler.fit_transform(X_test_2)
X_test_3_std = scaler.fit_transform(X_test_3)

# %% [markdown]
# Para poder definir cuál es la cantidad óptima de vecinos y cuál es el mejor método de cálculo de distancia, vamos a utilizar GridSearch. De esta manera logramos calcular todas las combinaciones posibles para luego analizar la opción óptima. Recordemos que para implementar la busqueda de **hiperparámetros** es necesario definir algunos elementos previamente, en este caso tenemos lo siguiente:
#
# **1.**  Un **estimador** = el modelo KNN.
#
# **2.**  Un **espacio de parámetros** = el parámetro `n_neighbors` con un rango de valores entre 1 y 30.
#
# **3.**  Un **esquema de validación cruzada** = Cross validation con 10 folds.
#
# **4.**  La **métrica de evaluación** = maximizar `accuracy`.
#
# **5.**  Un **método de busqueda** = `GridSearch`.
#
#
# A continuación definimos los 5 elementos listados previamente. En este caso utilizaremos el método `GridSearchCV` para exlorar un arreglo de tres dimensiones, correspondientes a lo parámetros `n_neighbors`, `weight` y `p`(distancia).

# %% [markdown]
# Ahora, definimos una función que tiene como entradas los conjutos de traint y test, y realiza lo siguiente:
# * Define el modelo y sus parámetros
# * Entrena el modelo utilizando el método `.fit` de grid
# * Evalua los resultados de cross validation
# * Predice etiquetas para X_test
# * Genera la matriz de confusión
# * Muestra un reporte de las principales métricas de evaluación

# %%
def knn_grid_cv (X_train, X_test, Y_train, Y_test, feature_id):
    
    # 1-Instanciamos el modelo
    knn = KNeighborsClassifier()

    # Utilizamos el método get_params para conocer todos los parametros del modelo
    print("Los parametros del modelo son: ")
    print(knn.get_params())
    
    # 2-Definimos el espacio de parámetros que queremos testear
    parameter_space = {
        "n_neighbors": range(1,200),
        "weights": ["uniform", "distance"],
        "p": [1, 2, 3] 
        # p = 1 (manhattan_distance (l1)),
        # p = 2 (euclidean_distance (l2)), 
        # for arbitrary p (minkowski_distance (l_p))
    }

    # 3-Definimos el método de validación cruzada con el método StratifiedKFold
    folds = StratifiedKFold(n_splits=10, random_state=123, shuffle=True)

    # 4-Definimos la métrica de evaluación = accuracy
    # 5-Definimos el método de búsqueda
    grid = GridSearchCV(estimator=knn, param_grid=parameter_space, 
                        cv=folds, scoring='accuracy', n_jobs=4)
    print('\n', grid)
    
    # Ajustamos el modelo
    grid.fit(X_train, Y_train)

    # Analizamos resultados de cross validation
    #cv_results = pd.DataFrame(grid.cv_results_)
    #cv_results.head(3)
    
    # Identificamos el parámetro con mejor score y los principales resultados
    print("\nEl mejor estimador es: \n ", grid.best_estimator_)
    print("\nBest accuracy:\n ", grid.best_score_, "\n")

    # Aplicamos el modelo
    Y_pred_grid = grid.predict(X_test)
    
    # Generamos la matriz de confusion
    conf_matrix = confusion_matrix(Y_test, Y_pred_grid)
    ax = sns.heatmap(conf_matrix, annot=True, xticklabels = Y.unique(), yticklabels = Y.unique(), linewidths=.5, cmap="YlGnBu")
    ax.set(xlabel='Prediction', ylabel='Ground truth', title="Confusion Matrix")

    # Mostramos reporte de métricas de evaluación
    print(classification_report(Y_test, Y_pred_grid))
    
    # Registramos el accuracy y la matriz de confusión en el DataFrame "resultados"
    acc = accuracy_score(Y_test, Y_pred_grid)
    print("\nAccuracy = ", acc)
    print("\n")
    note = 'KNN con CV 10 fold'

    resultados.loc[len(resultados.index)] = [acc, conf_matrix, feature_id, note]

# %%
# COMBINACIÓN 1 - TODAS LAS FEATURES
knn_grid_cv(X_train_1_std, X_test_1_std, Y_train, Y_test, 1)
# Out:
# Los parametros del modelo son:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=KNeighborsClassifier(), n_jobs=4,
#              param_grid={'n_neighbors': range(1, 200), 'p': [1, 2, 3],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   KNeighborsClassifier(n_neighbors=27, p=1)
#
# Best accuracy:
#   0.462020905923345
#
#               precision    recall  f1-score   support
#
#            C       0.63      0.55      0.59        31
#           PF       0.35      0.18      0.24        33
#           PG       0.68      0.45      0.55        33
#           SF       0.34      0.46      0.39        37
#           SG       0.44      0.63      0.52        43
#
#     accuracy                           0.46       177
#    macro avg       0.49      0.45      0.46       177
# weighted avg       0.48      0.46      0.46       177
#
#
# Accuracy =  0.4632768361581921

# %%
# COMBINACIÓN 2 - eliminando features con colinalidad (eliminamos intentos y valores porcentuales)
knn_grid_cv(X_train_2_std, X_test_2_std, Y_train, Y_test, 2)
# Out:
# Los parametros del modelo son:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=KNeighborsClassifier(), n_jobs=4,
#              param_grid={'n_neighbors': range(1, 200), 'p': [1, 2, 3],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   KNeighborsClassifier(n_neighbors=116, p=3, weights='distance')
#
# Best accuracy:
#   0.47735191637630664
#
#               precision    recall  f1-score   support
#
#            C       0.62      0.52      0.56        31
#           PF       0.30      0.24      0.27        33
#           PG       0.55      0.36      0.44        33
#           SF       0.00      0.00      0.00        37
#           SG       0.39      0.79      0.52        43
#
#     accuracy                           0.40       177
#    macro avg       0.37      0.38      0.36       177
# weighted avg       0.36      0.40      0.36       177
#
#
# Accuracy =  0.3954802259887006

# %%
# COMBINACIÓN 3 - features de mayor correlación absoluta
knn_grid_cv(X_train_3_std, X_test_3_std, Y_train, Y_test, 3)
# Out:
# Los parametros del modelo son:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=KNeighborsClassifier(), n_jobs=4,
#              param_grid={'n_neighbors': range(1, 200), 'p': [1, 2, 3],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   KNeighborsClassifier(n_neighbors=19)
#
# Best accuracy:
#   0.4961672473867596
#
#               precision    recall  f1-score   support
#
#            C       0.55      0.58      0.56        31
#           PF       0.37      0.30      0.33        33
#           PG       0.58      0.58      0.58        33
#           SF       0.35      0.24      0.29        37
#           SG       0.38      0.51      0.44        43
#
#     accuracy                           0.44       177
#    macro avg       0.44      0.44      0.44       177
# weighted avg       0.44      0.44      0.43       177
#
#
# Accuracy =  0.4406779661016949

# %%
resultados[3:6]
# Out:
#    Accuracy                                   Confusion Matrix Feature ID  \
# 3  0.463277  [[17, 4, 0, 7, 3], [9, 6, 1, 10, 7], [0, 1, 15...          1
# 4  0.395480  [[16, 5, 0, 5, 5], [8, 8, 2, 6, 9], [0, 1, 12,...          2
# 5  0.440678  [[18, 4, 0, 3, 6], [13, 10, 1, 4, 5], [0, 1, 1...          3
#
#                Modelo
# 3  KNN con CV 10 fold
# 4  KNN con CV 10 fold
# 5  KNN con CV 10 fold

# %% [markdown]
# De la tabla de resultados, se observa que los tres modelos superan el $39.5$% de accuracy score del modelo con Naive Bayes en las tres combinaciones de features. Es decir, el modelo KNN muestra mejor desempeño respecto al modelo Naive Bayes.
#
# El modelo de KNN con mejor accuracy score es el de la combinación 1 (todas las features), donde $accuracy  score=46.32$%. Para este modelo la mejor combinación de hiperparametros es: $n_neighbors=27$ y $p=1$.
#
# De la matrices de confusión se observa los siguiente:
#
#   * `SF` continua como la categoría con mayor cantidad de predicciones correctas, pero también como la categoría con mayor predicciones incorrectas _(columna 5)_ lo que genera un error de clasificación alto.
#
#
#   * `PG` mejoró considerablemente la cantidad de predicciones correctas _(columna 4)_. Sin embargo, ahora se tiene un caso similar al que se tenia inicialmente en la _columna 5_, el algoritmo aprendió a clasificar la categoría `PG`mejor que el resto de las categorías.

# %% [markdown]
# ---
# <a id="modelo_LR"></a>
# #### 3.2 Modelo de Regresión Logística
# [Ir al inicio del módulo 3](#modulo_03)
#
# <p

# %% [markdown]
# Vamos a evaluar el modelo de Regresión Logística usando cross validation y la configuración de un modelo multi-etiqueta. Utilizaremos las variables estandarizadas definidas al inicio del modelo KNN y el método GridSearch para evaluar distintas combinaciones de los parámetros
#
# * `C`:Inverso de la fuerza de regularización. Los valores más pequeños especifican una regularización más fuerte.
# * `penalty`: Norma de penalización
# * `solver`: Algoritmo a utilizar para el problema de optimizaciónInverso de la fuerza de regularización, Los valores más pequeños especifican una regularización más fuerte.
#
# Continuando con la línea de trabajo, a continuación definimos una función que tiene como entradas los conjutos de traint, test, y un feature_id.  La función realiza lo siguiente:
# * Define el modelo y sus parámetros
# * Entrena el modelo utilizando el método `.fit` de grid
# * Evalua los resultados de cross validation
# * Predice etiquetas para X_test
# * Genera la matriz de confusión
# * Muestra un reporte de las principales métricas de evaluación

# %%
def lr_grid_cv (X_train, X_test, Y_train, Y_test, feature_id):
    
    # 1-Instanciamos el modelo
    # For ‘multinomial’ the loss minimised is the multinomial loss fit across 
    # the entire probability distribution, even when the data is binary. 
    lr = LogisticRegression(multi_class='multinomial')

    # Utilizamos el método get_params para conocer todos los parametros del modelo
    print("Los parametros del modelo son: ")
    print(lr.get_params())
    
    # 2-Definimos el espacio de parámetros que queremos testear
    parameter_space = {
        "C": [1, 10, 100, 1000], # Inverse of regularization strength
        "penalty":  ['l1', 'l2','elasticnet', 'none'], # 'saga' - ['elasticnet', 'l1', 'l2', 'none'] 
        "solver": ["saga"] # Algorithm to use in the optimization problem
    }

    # 3-Definimos el método de validación cruzada con el método StratifiedKFold
    folds = StratifiedKFold(n_splits=10, random_state=123, shuffle=True)

    # 4-Definimos la métrica de evaluación = accuracy
    # 5-Definimos el método de búsqueda
    grid = GridSearchCV(estimator=lr, param_grid=parameter_space, 
                        cv=folds, scoring='accuracy', n_jobs=4)
    print('\n', grid)
    
    # Ajustamos el modelo
    grid.fit(X_train, Y_train)

    # Analizamos resultados de cross validation
    #cv_results = pd.DataFrame(grid.cv_results_)
    #cv_results.head(3)
    
    # Identificamos el parámetro con mejor score y los principales resultados
    print("\nEl mejor estimador es: \n ", grid.best_estimator_)
    print("\nBest accuracy:\n ", grid.best_score_, "\n")

    # Aplicamos el modelo
    Y_pred_grid = grid.predict(X_test)
    
    # Generamos la matriz de confusion
    conf_matrix = confusion_matrix(Y_test, Y_pred_grid)
    ax = sns.heatmap(conf_matrix, annot=True, xticklabels = Y.unique(), yticklabels = Y.unique(), linewidths=.5, cmap="YlGnBu")
    ax.set(xlabel='Prediction', ylabel='Ground truth', title="Confusion Matrix")

    # Mostramos reporte de métricas de evaluación
    print(classification_report(Y_test, Y_pred_grid))
    
    # Registramos el accuracy y la matriz de confusión en el DataFrame "resultados"
    acc = accuracy_score(Y_test, Y_pred_grid)
    print("\nAccuracy = ", acc)
    print("\n")
    note = 'LogReg con CV 10 fold'

    resultados.loc[len(resultados.index)] = [acc, conf_matrix, feature_id, note]

# %%
# COMBINACIÓN 1 - TODAS LAS FEATURES
lr_grid_cv(X_train_1_std, X_test_1_std, Y_train, Y_test, 1)
# Out:
# Los parametros del modelo son:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=LogisticRegression(multi_class='multinomial'), n_jobs=4,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['saga']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   LogisticRegression(C=10, multi_class='multinomial', solver='saga')
#
# Best accuracy:
#   0.5011033681765389
#
#               precision    recall  f1-score   support
#
#            C       0.62      0.65      0.63        31
#           PF       0.35      0.27      0.31        33
#           PG       0.61      0.70      0.65        33
#           SF       0.38      0.35      0.37        37
#           SG       0.51      0.56      0.53        43
#
#     accuracy                           0.50       177
#    macro avg       0.49      0.50      0.50       177
# weighted avg       0.49      0.50      0.49       177
#
#
# Accuracy =  0.5028248587570622

# %%
# COMBINACIÓN 2 - eliminando features con colinalidad (eliminamos intentos y valores porcentuales)
lr_grid_cv(X_train_2_std, X_test_2_std, Y_train, Y_test, 2)
# Out:
# Los parametros del modelo son:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=LogisticRegression(multi_class='multinomial'), n_jobs=4,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['saga']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   LogisticRegression(C=1, multi_class='multinomial', penalty='l1', solver='saga')
#
# Best accuracy:
#   0.4576074332171894
#
#               precision    recall  f1-score   support
#
#            C       0.56      0.58      0.57        31
#           PF       0.32      0.24      0.28        33
#           PG       0.59      0.67      0.63        33
#           SF       0.38      0.16      0.23        37
#           SG       0.42      0.65      0.51        43
#
#     accuracy                           0.46       177
#    macro avg       0.45      0.46      0.44       177
# weighted avg       0.45      0.46      0.44       177
#
#
# Accuracy =  0.4632768361581921

# %%
# COMBINACIÓN 3 - features de mayor correlación absoluta
lr_grid_cv(X_train_3_std, X_test_3_std, Y_train, Y_test, 3)
# Out:
# Los parametros del modelo son:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=LogisticRegression(multi_class='multinomial'), n_jobs=4,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['saga']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   LogisticRegression(C=1, multi_class='multinomial', solver='saga')
#
# Best accuracy:
#   0.510452961672474
#
#               precision    recall  f1-score   support
#
#            C       0.62      0.65      0.63        31
#           PF       0.29      0.27      0.28        33
#           PG       0.65      0.67      0.66        33
#           SF       0.43      0.24      0.31        37
#           SG       0.47      0.65      0.55        43
#
#     accuracy                           0.50       177
#    macro avg       0.49      0.50      0.49       177
# weighted avg       0.49      0.50      0.48       177
#
#
# Accuracy =  0.4971751412429379

# %%
resultados[6:9]
# Out:
#    Accuracy                                   Confusion Matrix Feature ID  \
# 6  0.502825  [[20, 6, 1, 2, 2], [10, 9, 0, 12, 2], [0, 0, 2...          1
# 7  0.463277  [[18, 4, 0, 4, 5], [11, 8, 1, 4, 9], [1, 0, 22...          2
# 8  0.497175  [[20, 5, 0, 1, 5], [11, 9, 1, 8, 4], [0, 1, 22...          3
#
#                   Modelo
# 6  LogReg con CV 10 fold
# 7  LogReg con CV 10 fold
# 8  LogReg con CV 10 fold

# %% [markdown]
# De la tabla de resultados, se observa que los tres modelos superan el $46.32$% de accuracy score del modelo KNN en las tres combinaciones de features. Es decir, el modelo de Regresión Logística muestra mejor desempeño respecto al modelo KNN.
#
# El modelo de Regresión Logística con mejor accuracy score es el de la combinación **1** (todas las features), obteniendo un $accuracy  score=51.41$%. Para este modelo la mejor combinación de hiperparametros es: $C=1000$, $penalty=l1$,  y $solver=saga$
#
# De la matrices de confusión se observa los siguiente:
#
#   * `SF` continua como la categoría con mayor cantidad de predicciones correctas, pero también como la categoría con mayor predicciones incorrectas _(columna 5)_ lo que genera un error de clasificación alto.
#
#
# * Las predicciones de `PG` _(columna 4)_ ahora presentan una situación similar a`SF`, es decir, es una cateoría que el algoritmo aprendió a predecir, de manera que existe un error de clasificación alto porque dicha categoría resulta incluso cuando no se trata realmente de ella.

# %% [markdown]
# ---
# <a id="modelo_AC"></a>
# #### Modelo Árboles de Clasificación
# [Ir al inicio del módulo 3](#modulo_03)

# %% [markdown]
# En este caso los datos no van escalados
#
# Vamos a evaluar el modelo Árboles de Clasificación usando cross validation. Utilizaremos las variables **no estandarizadas**, definidas al inicio del módulo 2. Nuevamente utilizaremos el método GridSearch para evaluar distintas combinaciones de los parámetros
#
# * `criterion`:La función para medir la calidad de una división.
# * `max_depth`: profundidad máxima del árbol. Si no se especifica, los nodos se expanden hasta que todas las hojas sean puras o hasta que todas las hojas contengan
# * `min_samples_split`: cantidad mínima requerida para dividir un nodo interno
# * `min_samples_leaf`: cantidad mínima de muestras requeridas para estar en un nodo hoja
#
# Continuando con la línea de trabajo, a continuación definimos una función que tiene como entradas los conjutos de traint, test (sin estandarizar), y un feature_id.  La función realiza lo siguiente:
# * Define el modelo y sus parámetros
# * Entrena el modelo utilizando el método `.fit` de grid
# * Evalua los resultados de cross validation
# * Predice etiquetas para X_test
# * Genera la matriz de confusión
# * Muestra un reporte de las principales métricas de evaluación

# %%
def tree_grid_cv (X_train, X_test, Y_train, Y_test, feature_id):
    
    # 1-Instanciamos el modelo
    tree_model = tree.DecisionTreeClassifier(random_state=42)

    # Utilizamos el método get_params para conocer todos los parametros del modelo
    print("Los parametros del modelo son: ")
    print(tree_model.get_params())
    
    # 2-Definimos el espacio de parámetros que queremos testear
    parameter_space = {
        'criterion': ['gini', 'entropy'],
        'max_depth' : range(1,30),
        'min_samples_split' : range(1,30, 5),
        'min_samples_leaf' : range(1,5)
    }

    # 3-Definimos el método de validación cruzada con el método StratifiedKFold
    folds = StratifiedKFold(n_splits=10, random_state=123, shuffle=True)

    # 4-Definimos la métrica de evaluación = accuracy
    # 5-Definimos el método de búsqueda
    grid = GridSearchCV(estimator=tree_model, param_grid=parameter_space, 
                        cv=folds, scoring='accuracy', n_jobs=4)
    print('\n', grid)
    
    # Ajustamos el modelo
    grid.fit(X_train, Y_train)

    # Analizamos resultados de cross validation
    #cv_results = pd.DataFrame(grid.cv_results_)
    #cv_results.head(3)
    
    # Identificamos el parámetro con mejor score y los principales resultados
    print("\nEl mejor estimador es: \n ", grid.best_estimator_)
    print("\nBest accuracy:\n ", grid.best_score_, "\n")

    # Aplicamos el modelo
    Y_pred_grid = grid.predict(X_test)
    
    # Generamos la matriz de confusion
    conf_matrix = confusion_matrix(Y_test, Y_pred_grid)
    ax = sns.heatmap(conf_matrix, annot=True, xticklabels = Y.unique(), yticklabels = Y.unique(), linewidths=.5, cmap="YlGnBu")
    ax.set(xlabel='Prediction', ylabel='Ground truth', title="Confusion Matrix")
    
    # Mostramos reporte de métricas de evaluación
    print(classification_report(Y_test, Y_pred_grid))
    
    # Registramos el accuracy y la matriz de confusión en el DataFrame "resultados"
    acc = accuracy_score(Y_test, Y_pred_grid)
    print("\nAccuracy = ", acc)
    print("\n")
    note = 'DeciTree con CV 10 fold'

    resultados.loc[len(resultados.index)] = [acc, conf_matrix, feature_id, note]
    
    dot_data = tree.export_graphviz(grid.best_estimator_, out_file=None,
                                    feature_names=X_train.columns, filled=True)
    
    graph = pydotplus.graph_from_dot_data(dot_data)
    display(Image(graph.create_png()))
    
    importance_df = pd.DataFrame({
        "atributo": X_train.columns,
        "importancia": grid.best_estimator_.feature_importances_
    }).sort_values("importancia", ascending=False)
    display(importance_df)

# %%
# COMBINACIÓN 1 - TODAS LAS FEATURES
tree_grid_cv(X_train_1, X_test_1, Y_train, Y_test, 1)
# Out:
# Los parametros del modelo son:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 42, 'splitter': 'best'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=DecisionTreeClassifier(random_state=42), n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 30),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 30, 5)},
#              scoring='accuracy')
#
# El mejor estimador es:
#   DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_split=6,
#                        random_state=42)
#
# Best accuracy:
#   0.4454703832752613
#
#               precision    recall  f1-score   support
#
#            C       0.50      0.52      0.51        31
#           PF       0.38      0.15      0.22        33
#           PG       0.48      0.45      0.47        33
#           SF       0.00      0.00      0.00        37
#           SG       0.31      0.72      0.43        43
#
#     accuracy                           0.38       177
#    macro avg       0.34      0.37      0.32       177
# weighted avg       0.32      0.38      0.32       177
#
#
# Accuracy =  0.3785310734463277
#    atributo  importancia
# 18      ORB     0.570257
# 21      AST     0.271786
# 7       FG%     0.157957
# 0        Rk     0.000000
# 14     eFG%     0.000000
# 25       PF     0.000000
# 24      TOV     0.000000
# 23      BLK     0.000000
# 22      STL     0.000000
# 20      TRB     0.000000
# 19      DRB     0.000000
# 17      FT%     0.000000
# 16      FTA     0.000000
# 15       FT     0.000000
# 13      2P%     0.000000
# 1       Age     0.000000
# 12      2PA     0.000000
# 11       2P     0.000000
# 10      3P%     0.000000
# 9       3PA     0.000000
# 8        3P     0.000000
# 6       FGA     0.000000
# 5        FG     0.000000
# 4        MP     0.000000
# 3        GS     0.000000
# 2         G     0.000000
# 26      PTS     0.000000

# %%
# COMBINACIÓN 2 - eliminando features con colinalidad (eliminamos intentos y valores porcentuales)
tree_grid_cv(X_train_2, X_test_2, Y_train, Y_test, 2)
# Out:
# Los parametros del modelo son:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 42, 'splitter': 'best'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=DecisionTreeClassifier(random_state=42), n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 30),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 30, 5)},
#              scoring='accuracy')
#
# El mejor estimador es:
#   DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_split=6,
#                        random_state=42)
#
# Best accuracy:
#   0.4454703832752613
#
#               precision    recall  f1-score   support
#
#            C       0.50      0.52      0.51        31
#           PF       0.38      0.15      0.22        33
#           PG       0.48      0.45      0.47        33
#           SF       0.00      0.00      0.00        37
#           SG       0.31      0.72      0.43        43
#
#     accuracy                           0.38       177
#    macro avg       0.34      0.37      0.32       177
# weighted avg       0.32      0.38      0.32       177
#
#
# Accuracy =  0.3785310734463277
#   atributo  importancia
# 0      ORB     0.570257
# 1      AST     0.271786
# 2      FG%     0.157957

# %%
# COMBINACIÓN 3 - features de mayor correlación absoluta
tree_grid_cv(X_train_3, X_test_3, Y_train, Y_test, 3)
# Out:
# Los parametros del modelo son:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 42, 'splitter': 'best'}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=DecisionTreeClassifier(random_state=42), n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 30),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 30, 5)},
#              scoring='accuracy')
#
# El mejor estimador es:
#   DecisionTreeClassifier(max_depth=6, min_samples_split=21, random_state=42)
#
# Best accuracy:
#   0.4432636469221835
#
#               precision    recall  f1-score   support
#
#            C       0.51      0.77      0.62        31
#           PF       0.28      0.15      0.20        33
#           PG       0.62      0.30      0.41        33
#           SF       0.23      0.27      0.25        37
#           SG       0.40      0.49      0.44        43
#
#     accuracy                           0.40       177
#    macro avg       0.41      0.40      0.38       177
# weighted avg       0.40      0.40      0.38       177
#
#
# Accuracy =  0.3954802259887006
#   atributo  importancia
# 0      ORB     0.338662
# 3      3PA     0.214509
# 2      AST     0.202159
# 4      3P%     0.130395
# 1      TRB     0.114276

# %%
resultados[9:12]
# Out:
#     Accuracy                                   Confusion Matrix Feature ID  \
# 9   0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          1
# 10  0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          2
# 11  0.395480  [[24, 1, 0, 2, 4], [13, 5, 0, 9, 6], [1, 1, 10...          3
#
#                      Modelo
# 9   DeciTree con CV 10 fold
# 10  DeciTree con CV 10 fold
# 11  DeciTree con CV 10 fold

# %% [markdown]
# De la tabla de resultados, se observa que los tres modelos tienen un accuracy score menor al $40.00$%. Es decir, el modelo de Árboles de Decisión muestra un desempeño peor respecto al modelo KNN y al modelo de Regresión Logística. Si comparamos este modelo con el modelo de Benchmark observamos que en 2 de los 3 casos el modelo de benchmark supera al modelo de Árboles de Decisión:

# %%
pd.concat([resultados[0:3], resultados[9:12]])
# Out:
#     Accuracy                                   Confusion Matrix Feature ID  \
# 0   0.361582  [[19, 2, 0, 0, 10], [8, 8, 2, 3, 12], [0, 1, 1...          1
# 1   0.406780  [[18, 4, 0, 3, 6], [9, 11, 1, 4, 8], [0, 1, 11...          2
# 2   0.401130  [[17, 2, 0, 4, 8], [9, 8, 1, 4, 11], [0, 1, 11...          3
# 9   0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          1
# 10  0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          2
# 11  0.395480  [[24, 1, 0, 2, 4], [13, 5, 0, 9, 6], [1, 1, 10...          3
#
#                         Modelo
# 0   Naive Bayes con CV 10 fold
# 1   Naive Bayes con CV 10 fold
# 2   Naive Bayes con CV 10 fold
# 9      DeciTree con CV 10 fold
# 10     DeciTree con CV 10 fold
# 11     DeciTree con CV 10 fold

# %% [markdown]
# El mejor accuracy score de este modelo (39.54%) y corresponde a la combinación **3**, con la siguiente combinación óptima de hiperparámetros:
#
#  * **Combinación 3**
#     (max_depth=6, min_samples_split=21, random_state=42)
#
# Otros detalles a observar son los siguientes
#  - El modelo de la combinación 1 tiene muchas variables de importancia, pero solamente 3 de ellas son realmente importantes (ORB,AST, y FG%)
#  - El modelo de la combinación 2 solo considera importantes tres variables (ORB,AST, y FG%) que coinciden con las features de mayor importancia en la combinación 1.
#  - En el caso de la combinación 3, el modelo considera importantes todas las features que se evaluan (ORB, 3PA, AST, 3P% y TRB).
#
# De la matrices de confusión se observa los siguiente:
#
#   * En la combinación 1 y 2, `SF` es la categodía con mayor número de predicciones totales (_columna 5_). Esto genera un alto error de clasificación. Mientras tanto, la categoría `PG` _(columna 4)_ no tuvo ninguna predicción ni correcta, ni incorrectamente. Esto significa que el modelo no aprendió a clacificar dicha categoría.
#
# * La _combinación 3_ tiene un balance entre las predicciones de las categorías `SF`y `PG`, Ya no se tiene una columna con 0´s y otra con todos sus elementos relativamente altos.

# %% [markdown]
# ---
# <a id="modulo_04"></a>
# ## Módulo 4 - Comparación de modelos
# [Ir a índice](#indice)

# %% [markdown]
# En este módulo haremos una comparación entre el performance de los modelos por medio del accuracy. Elegimos esta métrica ya que es una métrica que muestra el desempeño total del modelo, especificamente  mide la exactitud de las predicciones positivas o proporción de casos correctamente clasificados sobre el total de casos del test. Dado que el problema consiste en la clasificación de cinco etiquetas adecuadamente balanceadas, el accuracy resulta una métrica apropiada para comparar entre modelos.
#
# Una vez que se comparen los modelos y se identifique aquel con el mejor desempeño, analizaremos la matriz de confusión mediante distintas métricas.
#
# Hasta el momento hemos identificado cuál es la combinación de features con mejor accuracy score en cada modelo.
#
# * Para el modelo Gaussian Naive Bayes se obtuvo el mejor score accuracy en la combinación 2
# * Para el modelo KNN se obtuvo el mejor score accuracy en la combinación 1
# * Para el modelo Regresión Logística se obtuvo el mejor score accuracy en la combinación 1
# * Para el modelo Árboles de Clasificación se obtuvo el mejor score accuracy en la combinación 1

# %% [markdown]
# Ahora compararemos el performance de cada combinación de features ( Feature ID: 1,2,3) usando los 3 disntidos modelos. Es importante mencionar que en este análisis no consideramos los modelos Gaussian Naive Bayes, ya que ese modelo sólo fue definido como un punto de partida, donde se obtuvo un accuracy score entre $36.16$% - $40.67$%
#
# Haremos una función que grafique las matrices de confusión por cada combinación de features para poder compararlas. La función recibe la lista de matrices a graficar.

# %% [markdown]
# <p style="color:red"> Aquí falta revisar porque solo se grafican 3 matrices</p>

# %%
# definimos la función para graficar matrices

def grafica_matrices (resultado_com):
    lista_matrices = resultado_com.iloc[0:,1]
    descrip_modelo = resultado_com.iloc[0:,-1].values
    n = lista_matrices.shape[0]
    
    #Graficamos la matriz de confusión
    fig, ax = plt.subplots(1, n, figsize=(30,7))
    i = 0
    for m in lista_matrices:
        sns.heatmap(m, annot=True, xticklabels = Y.unique(), yticklabels = Y.unique(), linewidths=.5, cmap="YlGnBu", ax=ax[i])
        ax[i].set(xlabel='Prediction', ylabel='Ground truth', title="{}".format(descrip_modelo[i]))
        i = i+1

# %% [markdown]
# A continuación se presentan los resultados por cada combinación de features

# %% [markdown]
# ---
# #### 4.1 Resultados Combinación 1 - Todas las features

# %%
resultados_com1 = resultados[resultados["Feature ID"]==1].sort_values(by=['Accuracy'],ascending=False)
grafica_matrices(resultados_com1)
resultados_com1
# Out:
#    Accuracy                                   Confusion Matrix Feature ID  \
# 6  0.502825  [[20, 6, 1, 2, 2], [10, 9, 0, 12, 2], [0, 0, 2...          1
# 3  0.463277  [[17, 4, 0, 7, 3], [9, 6, 1, 10, 7], [0, 1, 15...          1
# 9  0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          1
# 0  0.361582  [[19, 2, 0, 0, 10], [8, 8, 2, 3, 12], [0, 1, 1...          1
#
#                        Modelo
# 6       LogReg con CV 10 fold
# 3          KNN con CV 10 fold
# 9     DeciTree con CV 10 fold
# 0  Naive Bayes con CV 10 fold

# %% [markdown]
# Para la **_Combinación 1_**, el modelo de Regresión Logística resultó ser aquel con el accuracy score más alto, $51.41$%. En segundo lugar se posiciona el modelo KNN. En el modelo de Árboles de Decisión obtenemos un accuracy score muy bajo ($37.78$%), muy parecido al modelo benchmark ($36.15$%).
#
# Se observa que en general se mantiene lo observado en el modulo de Naive Bayes: la categoría SF es la que tiene mayor cantidad de predicciones, tanto correctas como incorrectas. Al comparar este efecto para la combinación 1 de features, se visualiza que este efecto es más notorio en los dos modelos con menor accuracy score (Decision Tree y Naive Bayes). En el modelo de regresión logística se observa que la diagonal posee mayor cantidad de elementos correctamente clasificados.

# %% [markdown]
# ---
# #### 4.1 Resultados Combinación 2 - Eliminando features colineales

# %%
resultados_com2 = resultados[resultados["Feature ID"]==2].sort_values(by=['Accuracy'],ascending=False)
grafica_matrices(resultados_com2)
resultados_com2
# Out:
#     Accuracy                                   Confusion Matrix Feature ID  \
# 7   0.463277  [[18, 4, 0, 4, 5], [11, 8, 1, 4, 9], [1, 0, 22...          2
# 1   0.406780  [[18, 4, 0, 3, 6], [9, 11, 1, 4, 8], [0, 1, 11...          2
# 4   0.395480  [[16, 5, 0, 5, 5], [8, 8, 2, 6, 9], [0, 1, 12,...          2
# 10  0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          2
#
#                         Modelo
# 7        LogReg con CV 10 fold
# 1   Naive Bayes con CV 10 fold
# 4           KNN con CV 10 fold
# 10     DeciTree con CV 10 fold

# %% [markdown]
# Para la **_Combinación 2_**, nuevamente el modelo de Regresión Logística obtuvo el accuracy score más alto, $46.32$%. En segundo lugar se pocisiona el modelo Naive Bayes (acuracy score: $40.67$%). Notemos que entre estos dos modelos existe una diferencia del $5.5$% aproximadamente. Nuevamente el modelo de Árboles de Decisión se queda abajo como el modelo con peor performance.
#
# Se observa el mismo efecto que en el análisis anterior: la categoría SF es la que tiene mayor cantidad de predicciones, tanto correctas como incorrectas. Al comparar los modelos para la combinación 2 de features, se visualiza que este efecto es más notorio en los dos modelos con menor accuracy score (Decision Tree y KNN). En el modelo de regresión logística se observa que la diagonal posee mayor cantidad de elementos correctamente clasificados.

# %% [markdown]
# ---
# #### 4.3 Resultados Combinación 3 - Features de mayor correlación absoluta

# %%
resultados_com3 = resultados[resultados["Feature ID"]==3].sort_values(by=['Accuracy'],ascending=False)
grafica_matrices(resultados_com3)
resultados_com3
# Out:
#     Accuracy                                   Confusion Matrix Feature ID  \
# 8   0.497175  [[20, 5, 0, 1, 5], [11, 9, 1, 8, 4], [0, 1, 22...          3
# 5   0.440678  [[18, 4, 0, 3, 6], [13, 10, 1, 4, 5], [0, 1, 1...          3
# 2   0.401130  [[17, 2, 0, 4, 8], [9, 8, 1, 4, 11], [0, 1, 11...          3
# 11  0.395480  [[24, 1, 0, 2, 4], [13, 5, 0, 9, 6], [1, 1, 10...          3
#
#                         Modelo
# 8        LogReg con CV 10 fold
# 5           KNN con CV 10 fold
# 2   Naive Bayes con CV 10 fold
# 11     DeciTree con CV 10 fold

# %% [markdown]
# Para la **_Combinación 3_**, nuevamente el modelo de Regresión Logística obtuvo el accuracy score más alto, $49.71$%. En segundo lugar se encuentra el modelo KNN, con una diferencia porcentual del 5.5% aproximadamente. De la misma manera que para la _Combinación 2_, el modelo de árboles de decisión se posiciona hasta abajo como el peor modelo.
#
# Se observa el mismo efecto que en el análisis anterior: la categoría SF es la que tiene mayor cantidad de predicciones, tanto correctas como incorrectas. Al comparar los modelos para la combinación 3 de features, se visualiza que este efecto es más notorio en los dos modelos con menor accuracy score (Decision Tree y Naive Bayes). En el modelo de regresión logística se observa que la diagonal posee mayor cantidad de elementos correctamente clasificados.

# %% [markdown]
# ---
# <a id="modulo_05"></a>
# ## Conclusión
# [Ir a índice](#indice)

# %% [markdown]
# Finalmente visualizamos la lista de performance de todos los modelos.

# %%
# Mostramos la tabla de resultados final
resultados.sort_values("Accuracy", ascending=False)
# Out:
#     Accuracy                                   Confusion Matrix Feature ID  \
# 6   0.502825  [[20, 6, 1, 2, 2], [10, 9, 0, 12, 2], [0, 0, 2...          1
# 8   0.497175  [[20, 5, 0, 1, 5], [11, 9, 1, 8, 4], [0, 1, 22...          3
# 3   0.463277  [[17, 4, 0, 7, 3], [9, 6, 1, 10, 7], [0, 1, 15...          1
# 7   0.463277  [[18, 4, 0, 4, 5], [11, 8, 1, 4, 9], [1, 0, 22...          2
# 5   0.440678  [[18, 4, 0, 3, 6], [13, 10, 1, 4, 5], [0, 1, 1...          3
# 1   0.406780  [[18, 4, 0, 3, 6], [9, 11, 1, 4, 8], [0, 1, 11...          2
# 2   0.401130  [[17, 2, 0, 4, 8], [9, 8, 1, 4, 11], [0, 1, 11...          3
# 4   0.395480  [[16, 5, 0, 5, 5], [8, 8, 2, 6, 9], [0, 1, 12,...          2
# 11  0.395480  [[24, 1, 0, 2, 4], [13, 5, 0, 9, 6], [1, 1, 10...          3
# 9   0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          1
# 10  0.378531  [[16, 3, 0, 0, 12], [8, 5, 3, 0, 17], [2, 0, 1...          2
# 0   0.361582  [[19, 2, 0, 0, 10], [8, 8, 2, 3, 12], [0, 1, 1...          1
#
#                         Modelo
# 6        LogReg con CV 10 fold
# 8        LogReg con CV 10 fold
# 3           KNN con CV 10 fold
# 7        LogReg con CV 10 fold
# 5           KNN con CV 10 fold
# 1   Naive Bayes con CV 10 fold
# 2   Naive Bayes con CV 10 fold
# 4           KNN con CV 10 fold
# 11     DeciTree con CV 10 fold
# 9      DeciTree con CV 10 fold
# 10     DeciTree con CV 10 fold
# 0   Naive Bayes con CV 10 fold

# %% [markdown]
# Se observa que el modelo con mejor performance es el modelo de Regresión Logística Multiclase que utiliza la combinación 1 de features.
#
# En este caso tenemos: $accuracy=51.14$. con la siguiente combinación de hiperparámetros:
# `[C=100, multi_class='multinomial', solver='saga']`
#
# Vamos a presentar y analizar con más detalle este modelo:

# %%
best_model = resultados[resultados["Accuracy"]==resultados["Accuracy"].max()]
best_model
# Out:
#    Accuracy                                   Confusion Matrix Feature ID  \
# 6  0.502825  [[20, 6, 1, 2, 2], [10, 9, 0, 12, 2], [0, 0, 2...          1
#
#                   Modelo
# 6  LogReg con CV 10 fold

# %% [markdown]
# Para estudiar el modelo con mayor detalle, lo aplicaremos nuevamente considerando la combinación optima de hiperparámetros.

# %%
# COMBINACIÓN 1 - todas las features
# COMBINACIÓN 2 - eliminando features con colinalidad (eliminamos intentos y valores porcentuales)
# COMBINACIÓN 3 - features de mayor correlación absoluta

lr_grid_cv(X_train_1_std, X_test_1_std, Y_train, Y_test, 1)
# Out:
# Los parametros del modelo son:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
#  GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=123, shuffle=True),
#              estimator=LogisticRegression(multi_class='multinomial'), n_jobs=4,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['saga']},
#              scoring='accuracy')
#
# El mejor estimador es:
#   LogisticRegression(C=100, multi_class='multinomial', solver='saga')
#
# Best accuracy:
#   0.5034843205574913
#
#               precision    recall  f1-score   support
#
#            C       0.66      0.68      0.67        31
#           PF       0.38      0.30      0.34        33
#           PG       0.61      0.70      0.65        33
#           SF       0.38      0.35      0.37        37
#           SG       0.51      0.56      0.53        43
#
#     accuracy                           0.51       177
#    macro avg       0.51      0.52      0.51       177
# weighted avg       0.50      0.51      0.51       177
#
#
# Accuracy =  0.5141242937853108

# %% [markdown]
# Del reporte de clasificación podemos notar que las clases **C** y **PG** tienen los mejores valores para todas las métricas (precisión, recall y f-score).
#
# En el caso de la _precisión_, tienen un score de $66$% y $61$%, respectivamente. Esta métrica contempla todas las clasificaciones correctas para esta clase en función de todas las predicciones realizadas para esta categoría (precision = TP/(TP + FP)). Esto significa que, por ejemplo, en el caso de **C**, de las 32 veces que se predijo la etiqueta **C**, _(columna 1: 21+9+0+2+0=32)_, solo 21 de esas veces _(ver celda [1,1])_ fue una predicción correcta, así conseguimos $\frac{21}{32}=0.65625 ≈ 66$%
#
# En el caso del _recall_, tienen un score de $68$% y $70$%, respectivamente. Esta métrica contempla todas las clasificaciones correctas para esta clase en función de los valores reales para esta categoría (es decir, aquellos correctamente clasificados y aquellos que pertenecían a esta categoría pero que fueron incorrectamente clasificados) (recall = TP/(TP + FN)). Para calcular este valor, en el caso de la etiqueta **C**, se toman los 21 elementos correctamente clasificados y se los divide por la suma de elementos en la fila 1 _(21/(21+5+1+2+2).
#
# Por último, el F1 score define la media armónica entre la precisión y el recall, razón por la cuál sigue el mismo patrón que estas dos métricas en cuanto a respecta qué categoría tuvo un mejor o peor rendimiento.
#
#
# La posición **SF** es la que obtuvo peores resultados en cuanto a las métricas analizadas y tal como se espera en la matriz de confusión se observa que esta categoría tiene la mayor cantidad de predicciones incorrectas.
#
# Como conclusión se tiene que los modelos de regresión logística mostraron, en general, mejor desempeño respecto a los modelos KNN y Árboles de Decisión. Para cada combinación de features que se evaluaron, siempre el mejor accuracy score fue del modelo de regresión lógistica.
#
# El modelo de regresión logística para la _combinación 1_ es el modelo es el que logró mejorar en mayor medida el accuraccy inicial que se tenia con el modelo de Naive Bayes, sin embargo, se trata solo del $10$% de diferencia aproximadamente. Al obtener un acuracy del 50.34% en el modelo final, significa que al utilizarlo, aproximadamnete la mitad de las predicciones serán correctas, la otra mitad serán predicciones erróneas. Con esto, no podemos decir que se trata de un buen modelo para predecir, ya que $50.34$% es un accuracy score muy bajo. Como este score implicaría clasificar erróneamente a los jugadores la mitad de las veces, utilizar este modelo sería similar a tirar una moneda al azar, lo cual no hace que el modelo sea útil. Podría decirse que para resolver este problema de clasificación es necesario utilizar algún modelo de mayor complejidad.
